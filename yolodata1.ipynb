# %% [markdown]
# <a href="https://colab.research.google.com/github/advcloud/colabtest/blob/main/yolodata1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/EscVM/OIDv4_ToolKit.git
# !pip install -r OIDv4_ToolKit/requirements.txt
# Out:
# Cloning into 'OIDv4_ToolKit'...
# remote: Enumerating objects: 422, done.
# remote: Total 422 (delta 0), reused 0 (delta 0), pack-reused 422
# Receiving objects: 100% (422/422), 34.08 MiB | 36.02 MiB/s, done.
# Resolving deltas: 100% (146/146), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 3.9 MB 4.8 MB/s
# ...
#      |████████████████████████████████| 548 kB 68.5 MB/s
# ...
#      |████████████████████████████████| 79 kB 6.4 MB/s
# ...
#      |████████████████████████████████| 8.8 MB 33.2 MB/s
# ...
#      |████████████████████████████████| 138 kB 66.9 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.8
#     Uninstalling rsa-4.8:
#       Successfully uninstalled rsa-4.8
#   Attempting uninstall: docutils
# ...

# %%
# !python OIDv4_ToolKit/main.py downloader --classes Teapot --type_csv all --multiclasses 1
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading ['Teapot'] together.
#    [ERROR] | Missing the class-descriptions-boxable.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] y
# ...145%, 0 MB, 43322 KB/s, 0 seconds passed
# ...

# %%
from google.colab import files
# !zip -r /content/file.zip /content/OID/Dataset/
files.download("/content/file.zip")
# Out:
#   adding: content/OID/Dataset/ (stored 0%)
#   adding: content/OID/Dataset/test/ (stored 0%)
#   adding: content/OID/Dataset/test/Teapot/ (stored 0%)
#   adding: content/OID/Dataset/test/Teapot/acc3303f6fc08789.jpg (deflated 12%)
#   adding: content/OID/Dataset/test/Teapot/00672f3c5d893df4.jpg (deflated 1%)
#   adding: content/OID/Dataset/test/Teapot/77cd18e2d912c2f2.jpg (deflated 1%)
#   adding: content/OID/Dataset/test/Teapot/745e2c7ee3eb929b.jpg (deflated 0%)
#   adding: content/OID/Dataset/test/Teapot/7926b46e613c53a9.jpg (deflated 1%)
#   adding: content/OID/Dataset/test/Teapot/19b2500caf28f10a.jpg (deflated 0%)
#   adding: content/OID/Dataset/test/Teapot/93a140eb9e48f54f.jpg (deflated 0%)
#   adding: content/OID/Dataset/test/Teapot/22d9e033dadee2ab.jpg (deflated 1%)
#   adding: content/OID/Dataset/test/Teapot/4c9d2f2047a0134e.jpg (deflated 10%)
#   adding: content/OID/Dataset/test/Teapot/48af8e8a08f66a84.jpg (deflated 1%)
# ...
