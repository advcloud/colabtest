# %% [markdown]
# <a href="https://colab.research.google.com/github/advcloud/colabtest/blob/main/camtest1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/advcloud/colablib.git
# Out:
# ...
#   Cloning https://github.com/advcloud/colablib.git to /tmp/pip-req-build-dan45iur
#   Running command git clone -q https://github.com/advcloud/colablib.git /tmp/pip-req-build-dan45iur
# ...
#      |████████████████████████████████| 62 kB 660 kB/s
# ...
#      |████████████████████████████████| 85 kB 2.5 MB/s
# ...
#      |████████████████████████████████| 41 kB 543 kB/s
# ...
#   Created wheel for colablib: filename=colablib-1.0-py3-none-any.whl size=1360 sha256=c3d29892c814c0e9841d8e30499ca1667c5729e378f00cba842c2f27da94dfe1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tjoltegc/wheels/b5/c2/ac/7ed0bb567b972508dad7afde6343ba76aab2525c698c5770d2
# Successfully built colablib
# ...

# %%
# !git clone https://github.com/advcloud/colablib1.git
# Out:
# Cloning into 'colablib1'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 7 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (7/7), done.

# %%
# %cd colablib1
# Out:
# /content/colablib1

# %%
import functions1

# %%
def show_inference_from_webcam(total_iter=10):
  """Runs inference directly on your webcam for total_iter times!
  """
  vid = functions1.videoGrabber(showVideo=False)
  # the array based representation of the image will be used later in order to prepare the
  # result image with boxes and labels on it.
  try:
    n_iter = 0
    while n_iter <= total_iter:
      n_iter += 1
      image_np = functions1.np.array(vid(0))
      functions1.imshow(image_np)
  finally:
    vid(stop=True)

# %%
show_inference_from_webcam(total_iter=20)
# Out:
#   <div id="video_container">
#     <video autoplay
#     width=800 height=600></video>
#   </div>
#   <script>
#   var video_div = document.getElementById("video_container");
#   if(!false){
#     video_div.style.position = 'absolute';
#     video_div.style.left = '-9999px';
#   }
#   var video = document.querySelector('video');
#   var canvas = document.createElement('canvas');
#   canvas.id = "canvas_container";
#   var video_ready = false;
#   const nav = navigator.mediaDevices.getUserMedia({ video: true })
#     .then(stream => {
#       video.srcObject = stream;
#       sleep(100.000000).then(() => video_ready = true);
#       });
#   // https://stackoverflow.com/a/951057
#   function sleep(ms) {
#     return new Promise(resolve => setTimeout(resolve, ms));
#   }
#   function getData(ms){
#     if(video_ready){
#     return new Promise(resolve=>{
#       sleep(ms).then(() => {
#         var [w,h] = [video.offsetWidth, video.offsetHeight];
#         canvas.width = w;
# ...
